# %%
# Install & Imports
# !pip install pymoo==0.5.0

import pandas as pd
import numpy as np
from pymoo.core.problem import Problem
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize
from pymoo.factory import get_termination
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.operators.crossover.sbx import SBX
from pymoo.operators.mutation.pm import PM
from pymoo.util.nds.non_dominated_sorting import NonDominatedSorting
# Out:
# Requirement already satisfied: pymoo==0.5.0 in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.5.0) (2.0.2)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.5.0) (1.16.2)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.5.0) (3.10.0)
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.5.0) (1.8.0)
# Requirement already satisfied: cma==2.7 in /usr/local/lib/python3.12/dist-packages (from pymoo==0.5.0) (2.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.5.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.5.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.5.0) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.5.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.5.0) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.5.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.5.0) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3->pymoo==0.5.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3->pymoo==0.5.0) (1.17.0)

# %%
# Load Dataset
file_path = "Dummy_Lawyers.csv"
df = pd.read_csv(file_path)

# %%
# Define Optimization Problem
class LawyerSelectionProblem(Problem):
    def __init__(self, df):
        self.df = df.reset_index(drop=True)
        super().__init__(n_var=len(df), n_obj=4, n_constr=0, xl=0.0, xu=1.0)

    def _evaluate(self, X, out, *args, **kwargs):
        objs = []
        for weights in X:
            weights = np.clip(weights, 0, 1)
            weights /= np.sum(weights) + 1e-6  # normalize weights

            profile = (self.df[[
                "Years of active experience",
                "No of favoured settlements",
                "Client satisfaction (out of 10)",
                "Price"
            ]].T @ weights).values

            objs.append([
                -profile[0],  # maximize experience
                -profile[1],  # maximize settlements
                -profile[2],  # maximize satisfaction
                profile[3]    # minimize price
            ])
        out["F"] = np.array(objs)

# %%
# Run NSGA-2
def recommend_nsga2(domain, budget, seed=1, generations=100, pop_size=50):
    # Filter dataset
    filtered_df = df[(df["Domain"] == domain) & (df["Price"] <= budget)].reset_index(drop=True)
    if filtered_df.empty:
        print("No matching lawyers found for given filters.")
        return pd.DataFrame()

    # Define NSGA-II problem
    problem = LawyerSelectionProblem(filtered_df)
    algorithm = NSGA2(
        pop_size=pop_size,
        sampling=FloatRandomSampling(),
        crossover=SBX(prob=0.9, eta=15),
        mutation=PM(eta=20),
        eliminate_duplicates=True
    )
    termination = get_termination("n_gen", generations)

    # Run optimization
    res = minimize(problem, algorithm, termination, seed=seed, verbose=False)

    # Get Pareto-optimal indices
    pareto_idx = NonDominatedSorting().do(res.F, only_non_dominated_front=True)

    # Collect lawyers corresponding to Pareto front
    pareto_lawyers = []
    for i in pareto_idx:
        weights = np.clip(res.X[i], 0, 1)
        weights /= np.sum(weights) + 1e-6
        idx = np.argmax(weights)
        lawyer = filtered_df.iloc[idx].to_dict()
        lawyer["Objective Vector"] = res.F[i]
        lawyer["Price Objective"] = res.F[i][3]
        pareto_lawyers.append(lawyer)

    # Create DataFrame
    result_df = pd.DataFrame(pareto_lawyers).drop_duplicates(subset=["Name"])
    result_df = result_df.sort_values(by="Price Objective").reset_index(drop=True)

    # Show relevant columns
    return result_df[[
        "Name", "Domain", "Price", "Years of active experience",
        "No of favoured settlements", "Client satisfaction (out of 10)", "Price Objective"
    ]]

# %%
# Example 1
print("=== Civil Law, Budget 20000 ===")
display(recommend_nsga2("Civil Law", 20000))

# Example 2
print("=== Tax Law, Budget 30000 ===")
display(recommend_nsga2("Tax Law", 30000))

# Example 3
print("=== Corporate Law, Budget 50000 ===")
display(recommend_nsga2("Corporate Law", 50000))
# Out:
# === Civil Law, Budget 20000 ===
#                Name     Domain     Price  Years of active experience  \
# 0      Autumn Scott  Civil Law   7017.60                          14
# 1       Juan Kaiser  Civil Law  19032.32                          36
# 2  Patricia Cameron  Civil Law   8718.26                           8
# 3    Kimberly Garza  Civil Law  16347.37                          16
# 4      James Arnold  Civil Law  17657.24                           2
# 5   Daniel Figueroa  Civil Law  14729.53                          35
# 6  Nancy Richardson  Civil Law  11867.94                          25
# 7    Timothy Landry  Civil Law  19199.69                          19
#
#    No of favoured settlements  Client satisfaction (out of 10)  \
# 0                          39                              4.2
# 1                          26                              6.3
# 2                          40                              5.4
# 3                         153                              4.2
# 4                         184                              6.3
# 5                          44                              4.4
# 6                          52                              4.6
# 7                           0                              9.4
#
#    Price Objective
# 0     11092.332908
# 1     12408.713588
# 2     12741.773710
# 3     12745.236453
# 4     13682.400364
# 5     14577.830895
# 6     15013.970284
# 7     15357.435229
# === Tax Law, Budget 30000 ===
#                  Name   Domain     Price  Years of active experience  \
# 0       Lindsay Davis  Tax Law  13352.59                          18
# 1       Angela Martin  Tax Law  23019.82                          34
# 2   Michael Lopez Jr.  Tax Law  19832.51                           6
# 3        Mary Nichols  Tax Law  13597.30                           7
# 4   Dr. Wayne Jackson  Tax Law   9342.90                          26
# 5     Denise Thompson  Tax Law  20183.06                          29
# 6     Christine Brown  Tax Law  29839.41                          25
# 7        Matthew Gray  Tax Law  19545.63                          31
# 8    Edward Zimmerman  Tax Law  25581.01                          14
# 9      Kimberly Barry  Tax Law  18497.44                          10
# 10      Becky Roberts  Tax Law  24314.46                          11
# 11      Barbara Green  Tax Law  26332.73                           9
# 12    Jonathan Garcia  Tax Law  25508.15                          36
# 13        Morgan Wood  Tax Law  28203.46                          21
# 14       Shawn Wright  Tax Law  29278.57                           7
# 15   Jennifer Andrews  Tax Law  26698.13                          27
#
#     No of favoured settlements  Client satisfaction (out of 10)  \
# 0                          100                              4.1
# 1                           63                              6.1
# 2                           73                              8.8
# 3                          155                              4.2
# 4                            6                              4.2
# 5                           26                              5.6
# 6                          170                              8.3
# 7                           81                              4.1
# 8                           33                              9.3
# 9                           31                              8.5
# 10                          75                              8.5
# 11                         306                              5.0
# 12                          72                              7.2
# 13                         250                              5.5
# 14                         118                              9.5
# 15                          53                              9.4
#
#     Price Objective
# 0      17969.237112
# 1      18650.789343
# 2      19428.601217
# 3      20054.552636
# 4      20701.410942
# 5      20762.558887
# 6      20847.659355
# 7      20942.523588
# 8      21101.123770
# 9      21420.538992
# 10     21754.339895
# 11     21810.936249
# 12     22410.816729
# 13     22578.919539
# 14     22787.983250
# 15     23326.898463
# === Corporate Law, Budget 50000 ===
#                     Name         Domain     Price  Years of active experience  \
# 0         Allison Cooper  Corporate Law  16336.11                          13
# 1   Christopher Williams  Corporate Law  15413.83                          30
# 2        Taylor Anderson  Corporate Law   4255.01                           2
# 3           Richard Ruiz  Corporate Law  10569.22                           3
# 4         Jodi Gallagher  Corporate Law   7882.93                          14
# 5          Danielle Leon  Corporate Law  21402.89                          22
# 6           Thomas Smith  Corporate Law  35082.81                          11
# 7            Edward Lowe  Corporate Law  14919.76                           9
# 8            Sara Harris  Corporate Law  31756.04                          29
# 9          Timothy Henry  Corporate Law  34762.19                          25
# 10          Cynthia Bond  Corporate Law  26197.19                          35
# 11       Jennifer Wilson  Corporate Law  39950.42                          29
# 12        Jeffrey Jordan  Corporate Law  39540.79                          40
# 13        Deborah Berger  Corporate Law  38975.62                           7
#
#     No of favoured settlements  Client satisfaction (out of 10)  \
# 0                           16                              7.3
# 1                           26                              4.7
# 2                            5                              4.9
# 3                           64                              5.5
# 4                           31                              4.2
# 5                           20                              6.6
# 6                          217                              8.8
# 7                           51                              4.7
# 8                          216                              5.0
# 9                          167                              8.1
# 10                          96                              5.2
# 11                         262                              7.0
# 12                         115                              8.4
# 13                         216                              9.8
#
#     Price Objective
# 0      23346.193934
# 1      23897.747252
# 2      24108.001361
# 3      24227.980857
# 4      25766.488827
# 5      25839.788402
# 6      26192.727447
# 7      26765.426760
# 8      27191.671656
# 9      27313.527559
# 10     28432.027886
# 11     28930.633173
# 12     29846.420077
# 13     30428.862979
